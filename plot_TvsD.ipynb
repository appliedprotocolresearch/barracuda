# %%
import numpy as np
import pandas as pd
from pandas import DataFrame
import matplotlib
import matplotlib.pyplot as plt
import math
import scipy.io

# %%
num_nodes = 10000

max_blocks = 100

#Chyeck list of lists

delay_vector= np.arange(0,2.25,0.25)

num_delays=len(delay_vector)

num_trials = 100

max_len_tracker = np.zeros((num_delays, max_blocks+1, num_trials))

latest_k=5

no_poll_array_mean = np.array([])
no_poll_array_std = np.array([])
poll2_array_mean = np.array([])
poll2_array_std = np.array([])
latest5_poll2_array_mean = np.array([])
latest5_poll2_array_std = np.array([])
poll3_array_mean = np.array([])
poll3_array_std = np.array([])
poll4_array_mean = np.array([])
poll4_array_std = np.array([])
latest1_poll2_array_mean = np.array([])
latest1_poll2_array_std = np.array([])
latest3_poll2_array_mean = np.array([])
latest3_poll2_array_std = np.array([])

# %%
for d in delay_vector:

    our_path= 'TvsDresults/'+'n%d_T%d_D%.2f.csv'%(num_nodes,max_blocks,d)

    our_matrix = pd.read_csv(our_path).as_matrix()
    our_matrix = our_matrix[max_blocks,1:]
    '''
    if d not in [0,0.5,1,1.5,2.0]:
        our_matrix = max_blocks*our_matrix
    '''
    our_matrix_mean = np.mean(our_matrix)
    our_matrix_std = np.std(our_matrix)
    
    no_poll_array_mean = np.append(no_poll_array_mean,our_matrix_mean)
    no_poll_array_std = np.append(no_poll_array_std,our_matrix_std)
    
    
print(no_poll_array_mean)
print(no_poll_array_std)

for d in delay_vector:

    our_path= 'TvsDresults/'+'poll2_n%d_T%d_D%.2f.csv'%(num_nodes,max_blocks,d)

    our_matrix = pd.read_csv(our_path).as_matrix()

    our_matrix = our_matrix[max_blocks,1:]
    our_matrix_mean = np.mean(our_matrix)
    our_matrix_std = np.std(our_matrix)
    
    poll2_array_mean = np.append(poll2_array_mean,our_matrix_mean)
    poll2_array_std = np.append(poll2_array_std,our_matrix_std)
    
    
print(poll2_array_mean)
print(poll2_array_std)

for d in delay_vector:

    our_path= 'latest5/'+'latest_5_poll2_n%d_T%d_D%.2f.csv'%(num_nodes,max_blocks,d)

    our_matrix = pd.read_csv(our_path).as_matrix()

    our_matrix = our_matrix[max_blocks,1:]
    our_matrix_mean = np.mean(our_matrix)
    our_matrix_std = np.std(our_matrix)
    
    latest5_poll2_array_mean = np.append(latest5_poll2_array_mean,our_matrix_mean)
    latest5_poll2_array_std = np.append(latest5_poll2_array_std,our_matrix_std)
    
    
print(latest5_poll2_array_mean)
print(latest5_poll2_array_std)

for d in delay_vector:

    our_path= 'latest5/'+'latest_1_poll2_n%d_T%d_D%.2f.csv'%(num_nodes,max_blocks,d)

    our_matrix = pd.read_csv(our_path).as_matrix()

    our_matrix = our_matrix[max_blocks,1:]
    our_matrix_mean = np.mean(our_matrix)
    our_matrix_std = np.std(our_matrix)
    
    latest1_poll2_array_mean = np.append(latest1_poll2_array_mean,our_matrix_mean)
    latest1_poll2_array_std = np.append(latest1_poll2_array_std,our_matrix_std)
    
    
print(latest1_poll2_array_mean)
print(latest1_poll2_array_std)

for d in delay_vector:

    our_path= 'latest5/'+'latest_3_poll2_n%d_T%d_D%.2f.csv'%(num_nodes,max_blocks,d)

    our_matrix = pd.read_csv(our_path).as_matrix()

    our_matrix = our_matrix[max_blocks,1:]
    our_matrix_mean = np.mean(our_matrix)
    our_matrix_std = np.std(our_matrix)
    
    latest3_poll2_array_mean = np.append(latest3_poll2_array_mean,our_matrix_mean)
    latest3_poll2_array_std = np.append(latest3_poll2_array_std,our_matrix_std)
    
    
print(latest3_poll2_array_mean)
print(latest3_poll2_array_std)


'''
for d in delay_vector:

    our_path= 'TvsDresults/'+'poll3_n%d_T%d_D%.2f.csv'%(num_nodes,max_blocks,d)

    our_matrix = pd.read_csv(our_path).as_matrix()

    our_matrix = our_matrix[max_blocks,1:]
    our_matrix_mean = np.mean(our_matrix)
    our_matrix_std = np.std(our_matrix)
    
    poll3_array_mean = np.append(poll3_array_mean,our_matrix_mean)
    poll3_array_std = np.append(poll3_array_std,our_matrix_std)
    
    
print(poll3_array_mean)
print(poll3_array_std)

for d in delay_vector:

    our_path= 'TvsDresults/'+'poll4_n%d_T%d_D%.2f.csv'%(num_nodes,max_blocks,d)

    our_matrix = pd.read_csv(our_path).as_matrix()

    our_matrix = our_matrix[max_blocks,1:]
    our_matrix_mean = np.mean(our_matrix)
    our_matrix_std = np.std(our_matrix)
    
    poll4_array_mean = np.append(poll4_array_mean,our_matrix_mean)
    poll4_array_std = np.append(poll4_array_std,our_matrix_std)
    
    
print(poll4_array_mean)
print(poll4_array_std)
'''
# Out:
# [ 100.     98.17   86.81   75.48   66.58   59.98   55.06   50.61   46.56]
# [ 0.          1.28883668  2.77739086  3.1732633   2.96033782  2.71285827
#   2.81005338  2.33193053  2.34657197]
# [ 100.     99.96   98.16   93.26   86.96   80.63   74.47   70.96   66.47]
# [ 0.          0.19595918  1.22245654  2.34358699  3.05260544  3.29440435
#   3.26941891  3.03288641  2.9680128 ]
# [ 100.     99.98   98.46   93.12   86.86   79.8    73.26   69.     63.98]
# [ 0.          0.14        1.25235778  2.16        2.45772252  2.95972972
#   2.7843132   2.95296461  2.79635477]
# [ 100.          100.           97.22222222   86.88888889   77.66666667
#    67.22222222   61.22222222   55.55555556   51.55555556]
# [ 0.          0.          1.39664501  2.0245408   3.71184291  3.392075
#   2.73973956  2.58676594  2.83278862]
# [ 100.          100.           98.           91.33333333   84.
#    77.33333333   69.11111111   64.22222222   60.44444444]
# ...

# %%
combined_plot = np.column_stack((delay_vector,latest1_poll2_array_mean/max_blocks,latest3_poll2_array_mean/max_blocks))
np.savetxt('latest13_poll2.txt', combined_plot, delimiter=' ')

# %%
num_nodes = 10000

max_blocks = 100

#Chyeck list of lists

delay_vector= np.arange(0,5.5,0.5)

num_delays=len(delay_vector)

num_trials = 25

max_len_tracker = np.zeros((num_delays, max_blocks+1, num_trials))

latest_k=5

no_poll_array_mean = np.array([])
no_poll_array_std = np.array([])
poll2_2_array_mean = np.array([])
poll2_2_array_std = np.array([])
poll2_6_array_mean = np.array([])
poll2_6_array_std = np.array([])
poll3_5_array_mean = np.array([])
poll3_5_array_std = np.array([])
poll4_4_array_mean = np.array([])
poll4_4_array_std = np.array([])

# %%
for d in delay_vector:

    our_path= 'hetronetwork/'+'poll_1_1_delay_poll1_dist2_n%d_T%d_D%.2f.csv'%(num_nodes,max_blocks,d)

    our_matrix = pd.read_csv(our_path).as_matrix()
    our_matrix = our_matrix[max_blocks,1:]
    '''
    if d not in [0,0.5,1,1.5,2.0]:
        our_matrix = max_blocks*our_matrix
    '''
    our_matrix_mean = np.mean(our_matrix)
    our_matrix_std = np.std(our_matrix)
    
    no_poll_array_mean = np.append(no_poll_array_mean,our_matrix_mean)
    no_poll_array_std = np.append(no_poll_array_std,our_matrix_std)
    
    
print(no_poll_array_mean)
print(no_poll_array_std)

for d in delay_vector:

    our_path= 'hetronetwork/'+'poll_2_2_delay_poll2_dist2_n%d_T%d_D%.2f.csv'%(num_nodes,max_blocks,d)

    our_matrix = pd.read_csv(our_path).as_matrix()

    our_matrix = our_matrix[max_blocks,1:]
    our_matrix_mean = np.mean(our_matrix)
    our_matrix_std = np.std(our_matrix)
    
    poll2_2_array_mean = np.append(poll2_2_array_mean,our_matrix_mean)
    poll2_2_array_std = np.append(poll2_2_array_std,our_matrix_std)
    
    
print(poll2_2_array_mean)
print(poll2_2_array_std)

for d in delay_vector:

    our_path= 'hetronetwork/'+'poll_2_6_delay_poll4_dist2_n%d_T%d_D%.2f.csv'%(num_nodes,max_blocks,d)

    our_matrix = pd.read_csv(our_path).as_matrix()

    our_matrix = our_matrix[max_blocks,1:]
    our_matrix_mean = np.mean(our_matrix)
    our_matrix_std = np.std(our_matrix)
    
    poll2_6_array_mean = np.append(poll2_6_array_mean,our_matrix_mean)
    poll2_6_array_std = np.append(poll2_6_array_std,our_matrix_std)
    
    
print(poll2_6_array_mean)
print(poll2_6_array_std)

for d in delay_vector:

    our_path= 'hetronetwork/'+'poll_3_5_delay_poll4_dist2_n%d_T%d_D%.2f.csv'%(num_nodes,max_blocks,d)

    our_matrix = pd.read_csv(our_path).as_matrix()

    our_matrix = our_matrix[max_blocks,1:]
    our_matrix_mean = np.mean(our_matrix)
    our_matrix_std = np.std(our_matrix)
    
    poll3_5_array_mean = np.append(poll3_5_array_mean,our_matrix_mean)
    poll3_5_array_std = np.append(poll3_5_array_std,our_matrix_std)
    
    
print(poll3_5_array_mean)
print(poll3_5_array_std)

for d in delay_vector:

    our_path= 'hetronetwork/'+'poll_4_4_delay_poll4_dist2_n%d_T%d_D%.2f.csv'%(num_nodes,max_blocks,d)

    our_matrix = pd.read_csv(our_path).as_matrix()

    our_matrix = our_matrix[max_blocks,1:]
    our_matrix_mean = np.mean(our_matrix)
    our_matrix_std = np.std(our_matrix)
    
    poll4_4_array_mean = np.append(poll4_4_array_mean,our_matrix_mean)
    poll4_4_array_std = np.append(poll4_4_array_std,our_matrix_std)
    
    
print(poll4_4_array_mean)
print(poll4_4_array_std)
# Out:
# [ 100.     51.24   39.6    33.48   29.12   28.24   25.4    24.24   21.8
#    20.04   18.84]
# [ 0.          3.73395233  3.84707681  3.04788451  3.1153812   3.24074066
#   2.69814751  2.42123935  2.84253408  2.10675105  1.56665248]
# [ 100.     69.32   51.8    43.2    36.72   33.76   31.2    29.32   27.88
#    25.08   23.72]
# [ 0.          3.23382127  2.54558441  3.62215406  2.70584552  2.58116253
#   2.78567766  2.98958191  2.25068878  2.49671785  1.75544866]
# [ 100.     81.32   62.52   51.12   44.72   39.36   35.96   33.2    30.48
#    28.84   27.28]
# [ 0.          3.22142825  2.99492905  2.33786227  2.23642572  1.74080441
#   1.84347498  2.0976177   2.0614558   1.73620275  1.58795466]
# [ 100.     85.48   68.2    57.04   49.64   44.28   40.64   37.6    34.56
#    32.4    30.8 ]
# [ 0.          2.11886762  2.65329983  2.74925444  1.78616908  2.3412817
#   2.24285532  2.48193473  1.79064234  1.97989899  1.78885438]
# ...

# %%
combined_plot = np.column_stack((delay_vector,no_poll_array_mean/max_blocks,poll2_2_array_mean/max_blocks,poll2_6_array_mean/max_blocks,poll3_5_array_mean/max_blocks,poll4_4_array_mean/max_blocks))
np.savetxt('exp_heteronetwork.txt', combined_plot, delimiter=' ')

# %%
matarray = []
matarray.append(delay_vector)
matarray.append(no_poll_array_mean/max_blocks)
matarray.append(no_poll_array_std/np.sqrt(100)/max_blocks)
matarray.append(poll2_array_mean/max_blocks)
matarray.append(poll2_array_std/np.sqrt(100)/max_blocks)
matarray.append(poll3_array_mean/max_blocks)
matarray.append(poll3_array_std/np.sqrt(100)/max_blocks)
matarray.append(poll4_array_mean/max_blocks)
matarray.append(poll4_array_std/np.sqrt(100)/max_blocks)
matarray = np.array(matarray)
print(matarray.shape)
scipy.io.savemat('matlabdata/zero_poll_delay_1.mat', mdict={'arr': matarray})
# Out:
# (9, 21)

# %%
lower_bound_array = np.array([])
finer_delay_vector = np.arange(0,5.01,0.01)
for d in delay_vector:
    if d==0:
        x = 0
    else:
        x = np.exp(-1/d)
    a = np.exp(-x/((1-x)**2))
    lower_bound_array = np.append(lower_bound_array,max_blocks*a)

plt.rcParams.update({'font.size': 28})
plt.figure(figsize=(20,14))
plt.errorbar(delay_vector,no_poll_array_mean/100,no_poll_array_std/np.sqrt(100)/100,color=(0.5,0,0))
plt.plot(delay_vector,lower_bound_array/100,color=(0.5,1,0))
plt.xlabel('Mean network delay, D')
plt.ylabel('Normalized main chain length')
plt.legend(['lower_bound','Experimental'])
#plt.title('Lower_bound_tightness')
plt.show()

# %%
#for symmetric network

num_nodes = 500

max_blocks = 100

#Chyeck list of lists

delay_vector= np.arange(0.1,1.1,0.1)

num_delays=len(delay_vector)

num_trials =16

max_len_tracker = np.zeros((num_delays, max_blocks+1, num_trials))

no_poll_array_mean = np.array([])
no_poll_array_std = np.array([])
poll5_array_mean = np.array([])
poll5_array_std = np.array([])

# %%
for d in delay_vector:

    if d==0.1:
        our_path= 'symmetric/'+'poll1_n%d_T%d_D%.2f.csv'%(num_nodes,50,d)

        our_matrix = pd.read_csv(our_path).as_matrix()
        our_matrix = our_matrix[50,1:]
        our_matrix_mean = np.mean(our_matrix)*2
        our_matrix_std = np.std(our_matrix)*2

    else:


        our_path= 'symmetric/'+'poll1_n%d_T%d_D%.2f.csv'%(num_nodes,max_blocks,d)

        our_matrix = pd.read_csv(our_path).as_matrix()
        our_matrix = our_matrix[max_blocks,1:]
        '''
        our_path2= 'hetronetwork/'+'extra_delay_dist2_n%d_T%d_D%.2f.csv'%(num_nodes,max_blocks,d)

        our_matrix2 = pd.read_csv(our_path2).as_matrix()
        our_matrix2 = our_matrix2[max_blocks,1:]
        our_matrix = np.append(our_matrix , our_matrix2)
        '''
        our_matrix_mean = np.mean(our_matrix)
        our_matrix_std = np.std(our_matrix)
    
    no_poll_array_mean = np.append(no_poll_array_mean,our_matrix_mean)
    no_poll_array_std = np.append(no_poll_array_std,our_matrix_std)
    
    
print(no_poll_array_mean)
print(no_poll_array_std)

for d in delay_vector:

    if d==0.1:
        our_path= 'symmetric/'+'poll5_n%d_T%d_D%.2f.csv'%(num_nodes,50,d)

        our_matrix = pd.read_csv(our_path).as_matrix()
        our_matrix = our_matrix[50,1:]
        our_matrix_mean = np.mean(our_matrix)*2
        our_matrix_std = np.std(our_matrix)*2
    
    else:
        our_path= 'symmetric/'+'poll5_n%d_T%d_D%.2f.csv'%(num_nodes,max_blocks,d)

        our_matrix = pd.read_csv(our_path).as_matrix()

        our_matrix = our_matrix[max_blocks,1:]
        '''
        our_path2= 'hetronetwork/'+'extra_delay_poll2_dist2_n%d_T%d_D%.2f.csv'%(num_nodes,max_blocks,d)

        our_matrix2 = pd.read_csv(our_path2).as_matrix()
        our_matrix2 = our_matrix2[max_blocks,1:]
        our_matrix = np.append(our_matrix , our_matrix2)
        '''
        our_matrix_mean = np.mean(our_matrix)
        our_matrix_std = np.std(our_matrix)
    
    poll2_array_mean = np.append(poll2_array_mean,our_matrix_mean)
    poll2_array_std = np.append(poll2_array_std,our_matrix_std)
    
    
print(poll2_array_mean)
print(poll2_array_std)

'''
for d in delay_vector:

    our_path= 'hetronetwork/'+'poll4_delay_dist2_n%d_T%d_D%.2f.csv'%(num_nodes,max_blocks,d)

    our_matrix = pd.read_csv(our_path).as_matrix()

    our_matrix = our_matrix[max_blocks,1:]
    
    our_path2= 'hetronetwork/'+'extra_delay_poll4_dist2_n%d_T%d_D%.2f.csv'%(num_nodes,max_blocks,d)

    our_matrix2 = pd.read_csv(our_path2).as_matrix()
    our_matrix2 = our_matrix2[max_blocks,1:]
    our_matrix = np.append(our_matrix , our_matrix2)
    
    our_matrix_mean = np.mean(our_matrix)
    our_matrix_std = np.std(our_matrix)
    
    poll4_array_mean = np.append(poll4_array_mean,our_matrix_mean)
    poll4_array_std = np.append(poll4_array_std,our_matrix_std)
    
    
print(poll4_array_mean)
print(poll4_array_std)
'''
# Out:
# [ 95.375   53.0625  39.6875  32.25    27.875   24.5625  22.625   20.
#   18.6875  17.8125]
# [ 3.44374433  1.43478004  1.48823511  0.96824584  1.21834929  0.78809501
#   0.85695683  1.17260394  0.9822646   1.07347275]
# [ 98.      64.3125  50.375   40.875   36.375   32.5     29.125   27.25
#   25.3125  23.25  ]
# [ 0.          2.11301769  1.16592238  2.0577597   1.49478259  1.36930639
#   1.36358901  1.3462912   1.26089006  1.25      ]
# ...

# %%
matarray = []
matarray.append(delay_vector)
matarray.append(no_poll_array_mean/max_blocks)
matarray.append(no_poll_array_std/np.sqrt(10)/max_blocks)
matarray.append(poll2_array_mean/max_blocks)
matarray.append(poll2_array_std/np.sqrt(10)/max_blocks)
#matarray.append(poll4_array_mean/max_blocks)
#matarray.append(poll4_array_std/np.sqrt(50)/max_blocks)
matarray = np.array(matarray)
print(matarray.shape)
scipy.io.savemat('matlabdata/homogeneous_symmetric.mat', mdict={'arr': matarray})
# Out:
# (5, 10)

# %%
plt.figure(figsize=(10,10))
plt.errorbar(delay_vector,no_poll_array_mean,no_poll_array_std/np.sqrt(10))
plt.errorbar(delay_vector,poll2_array_mean,poll2_array_std/np.sqrt(10))
plt.errorbar(delay_vector,latest5_poll2_array_mean,latest5_poll2_array_std/np.sqrt(10))
#plt.errorbar(delay_vector,poll3_array_mean,poll3_array_std/10)
#plt.errorbar(delay_vector,poll4_array_mean,poll4_array_std/10)
plt.xlabel('Delay')
plt.ylabel('Mean chain length')
plt.legend(['No_poll','2_poll','latest5_2poll'])
plt.title('Exponential homogeneous network')
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.errorbar(delay_vector,no_poll_array_mean,no_poll_array_std/4)
plt.errorbar(delay_vector,poll5_array_mean,poll5_array_std/4)
#plt.errorbar(delay_vector,poll3_array_mean,poll3_array_std/10)
#plt.errorbar(delay_vector,poll4_array_mean,poll4_array_std/10)
plt.xlabel('Delay')
plt.ylabel('Mean chain length')
plt.legend(['No_poll','5_poll'])
plt.title('Homogeneous network')
plt.show()

# %%
delay_poll2_array_mean = np.array([])
delay_poll2_array_std = np.array([])
delay_poll3_array_mean = np.array([])
delay_poll3_array_std = np.array([])
delay_poll4_array_mean = np.array([])
delay_poll4_array_std = np.array([])

# %%
for d in delay_vector:

    our_path= 'poll_delay_conservative/'+'poll2_n%d_T%d_D%.2f.csv'%(num_nodes,max_blocks,d)

    our_matrix = pd.read_csv(our_path).as_matrix()

    our_matrix = our_matrix[max_blocks,1:]
    our_matrix_mean = np.mean(our_matrix)
    our_matrix_std = np.std(our_matrix)
    
    delay_poll2_array_mean = np.append(delay_poll2_array_mean,our_matrix_mean)
    delay_poll2_array_std = np.append(delay_poll2_array_std,our_matrix_std)
    
    
print(delay_poll2_array_mean)
print(delay_poll2_array_std)

for d in delay_vector:

    our_path= 'poll_delay_conservative/'+'poll3_n%d_T%d_D%.2f.csv'%(num_nodes,max_blocks,d)

    our_matrix = pd.read_csv(our_path).as_matrix()

    our_matrix = our_matrix[max_blocks,1:]
    our_matrix_mean = np.mean(our_matrix)
    our_matrix_std = np.std(our_matrix)
    
    delay_poll3_array_mean = np.append(delay_poll3_array_mean,our_matrix_mean)
    delay_poll3_array_std = np.append(delay_poll3_array_std,our_matrix_std)
    
    
print(delay_poll3_array_mean)
print(delay_poll3_array_std)

for d in delay_vector:

    our_path= 'poll_delay_conservative/'+'delay2_poll4_n%d_T%d_D%.2f.csv'%(num_nodes,max_blocks,d)

    our_matrix = pd.read_csv(our_path).as_matrix()

    our_matrix = our_matrix[max_blocks,1:]
    our_matrix_mean = np.mean(our_matrix)
    our_matrix_std = np.std(our_matrix)
    
    delay_poll4_array_mean = np.append(delay_poll4_array_mean,our_matrix_mean)
    delay_poll4_array_std = np.append(delay_poll4_array_std,our_matrix_std)
    
    
print(delay_poll4_array_mean)
print(delay_poll4_array_std)
# Out:
# [ 100.       99.9375   96.0625   87.625    78.25     72.1875   66.5
#    60.1875   55.5      51.375    48.625    46.1875   42.25     40.5625
#    37.625    37.1875   35.8125   34.375    32.6875   31.6875   30.5     100.
#    99.9375   98.125    91.6875   85.8125   77.125    70.25     65.3125
#    61.3125   57.9375   55.       51.125    49.75     47.1875   45.
#    43.3125   43.       41.8125   39.875    37.8125   36.4375]
# [ 0.          0.24206146  1.7842628   2.57087048  3.19178633  2.766287
#   2.09165007  2.78878894  2.29128785  2.78107443  2.23257139  2.29724699
#   1.85404962  1.76666175  2.1469455   2.35103036  2.03773005  2.68967935
#   2.46776088  1.95955193  2.37170825  0.          0.24206146  1.40867846
#   2.93084352  2.55486668  3.33307291  2.79508497  3.47704526  3.21556274
#   2.33100702  2.64575131  1.9324531   1.75        2.32429425  2.91547595
#   1.60929915  2.          1.33317056  1.36358901  1.73992636  1.49869735]
# ...

# %%
plt.figure(figsize=(10,10))
plt.errorbar(delay_vector,no_poll_array_mean,no_poll_array_std/10)
plt.errorbar(delay_vector,poll2_array_mean,poll2_array_std/10)
plt.errorbar(delay_vector,delay_poll2_array_mean,delay_poll2_array_std/4)
plt.errorbar(delay_vector,poll3_array_mean,poll3_array_std/10)
plt.errorbar(delay_vector,delay_poll3_array_mean,delay_poll3_array_std/4)
plt.errorbar(delay_vector,poll4_array_mean,poll4_array_std/10)
#plt.errorbar(delay_vector,delay_poll4_array_mean,delay_poll4_array_std/4)

plt.xlabel('Delay')
plt.ylabel('Mean chain length')
plt.legend(['No_poll','2_poll','delay_2_poll','3_poll','delay_3_poll','4_poll'])
plt.title('Optimistic poll delay')
plt.show()
